# %% [markdown]
# # 4. Modeling

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import time
from itertools import product

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

# %%
import autoreload
# %load_ext autoreload
# %autoreload 2

import modeling as md

# %%
shops = [7, 10, 12, 14, 15, 16, 18, 19, 21, 22, 24, 25, 26, 28, 31, 34, 35, 36, 37, 38, 39, 41, 42, 44, 45, 46, 47, 48, 49, 50, 52, 53, 55, 56, 57, 58, 59]

# %% [markdown]
# ## LSTM Modeling

# %%
shops = [ 5,  4,  6,  3,  2,  7, 10, 12, 28, 31, 26, 25, 22, 24, 21, 15, 16, 18, 14, 19, 42, 50, 49, 53, 52, 47, 48, 57, 58, 59, 55, 56, 36, 37, 35, 38, 34, 46, 41, 44, 39, 45]

for shop in shops:
    
    # train test splitting in python script
    X_train_series, X_test_series, y_train, y_test = md.train_split(shop)
    
    # read in shop train data set to grab index further down
    ds = pd.read_csv('./data/clean_shops/shop_' + str(shop) + '.csv')
    
    # fit model using python script
    fitted_model = md.neural_net(X_train_series, X_test_series, y_train, y_test, shop)
    
    # transform test in order to make predictions
    test = md.compile_test(ds,shop)
    test.shape
    
    # predict
    test_array = model_lstm.predict(test)
    
    # transform test set after predictions
    md.after_predict(test_array, shop, test)
# Out:
# Train set shape:  (6303, 33, 1)
# Test set shape:  (2102, 33, 1)
# Epoch 1/15
# 13/13 [==============================] - 1s 55ms/step - loss: 0.8183 - val_loss: 0.9526
# Epoch 2/15
# 13/13 [==============================] - 1s 43ms/step - loss: 0.8074 - val_loss: 0.2749
# Epoch 3/15
# 13/13 [==============================] - 1s 43ms/step - loss: 0.7965 - val_loss: 0.1185
# Epoch 4/15
# 13/13 [==============================] - 1s 43ms/step - loss: 0.7880 - val_loss: 2.0854
# Epoch 5/15
# 13/13 [==============================] - 1s 44ms/step - loss: 0.7808 - val_loss: 1.1980
# Epoch 6/15
# 13/13 [==============================] - 1s 44ms/step - loss: 0.7758 - val_loss: 0.1867
# Epoch 7/15
# 13/13 [==============================] - 1s 44ms/step - loss: 0.7715 - val_loss: 1.3770
# Epoch 8/15
# 13/13 [==============================] - 1s 45ms/step - loss: 0.7694 - val_loss: 0.1224
# Train set shape:  (5517, 33, 1)
# Test set shape:  (1839, 33, 1)
# Epoch 1/15
# ...
